# %%
import os
import sys

# %%
os.getcwd()
# Out:
# 'd:\\Study_Unimi\\Coding_Python\\Project_2025\\My_project_DSE_2025\\presentation'

# %%
dir_path = "d:/Study_Unimi/Coding_Python/Project_2025/My_project_DSE_2025"
sys.path.append(os.path.abspath(dir_path))

# %% [markdown]
# # Import package from source_code

# %%
# import source
import importlib
import matplotlib.pyplot as plt

from source_code import clean_data
from source_code import processing
importlib.reload(clean_data)
importlib.reload(processing)
# Out:
# <module 'source_code.processing' from 'd:\\Study_Unimi\\Coding_Python\\Project_2025\\My_project_DSE_2025\\source_code\\processing.py'>

# %% [markdown]
# # Cleaned data and show 5 rows

# %%
file_name_read = "songs_data.csv"
file_name_save = "songs_cleaned.csv"
data_path = dir_path + '/Dataset/'
df = clean_data.clean_data( data_path,file_name_read,file_name_save)   
df.head()
# Out:
# Cleaned data saved to new file
#            artist                    song  duration_ms  explicit  year  \
# 0  britney spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      faith hill                 Breathe       250546     False  1999
# 3        bon jovi            It's My Life       224493     False  2000
# 4          *nsync             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  ...  acousticness  \
# 0          77         0.751   0.834    1    -5.444  ...        0.3000
# 1          79         0.434   0.897    0    -4.918  ...        0.0103
# 2          66         0.529   0.496    7    -9.007  ...        0.1730
# 3          78         0.551   0.913    0    -4.063  ...        0.0263
# 4          65         0.614   0.928    8    -4.806  ...        0.0408
#
#    instrumentalness  liveness  valence    tempo         genre  decade  \
# ...

# %% [markdown]
# # show number of songs per year

# %%
fig = processing.songs_per_year(df)
plt.show()

# %% [markdown]
# # The top 10 artists with the average popularity of their songs

# %%
# processing.top_artist_songs(df)
processing.plot_top_artists(processing.top10_artist_songs(df))
plt.show()
# Out:
# d:\Study_Unimi\Coding_Python\Project_2025\My_project_DSE_2025\source_code\processing.py:72: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df['artist'],rotation=45)

# %% [markdown]
# # Visuallize trend of feature music over time

# %%
processing.plot_trend_over_time(df)
plt.show()

# %% [markdown]
# # Show top 5 genres by number of song in each decade

# %%
processing.plot_top_genre(processing.top_genre_songs(df))
plt.show()

# %% [markdown]
# # the increasing/decreasing trend of energy_level over time.
# We see that high_level increases over the years

# %%
processing.trend_of_energy(df)
plt.show()
# Out:
# d:\Study_Unimi\Coding_Python\Project_2025\My_project_DSE_2025\source_code\processing.py:132: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sns.lineplot(

# %% [markdown]
# # Which genres are typically High/Medium/Low energy?
# High energy --> Pop, Hip-Hop

# %%
processing.plot_Energy_Genre(df)
plt.show()
# Out:
# d:\Study_Unimi\Coding_Python\Project_2025\My_project_DSE_2025\source_code\processing.py:152: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   y="count",
# d:\Study_Unimi\Coding_Python\Project_2025\My_project_DSE_2025\source_code\processing.py:162: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
# %reset -f
