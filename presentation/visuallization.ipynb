# %%
# import source
from source_code.processing import clean_data
from source_code import analysis

# %% [markdown]
# Cleaned data and show 5 rows

# %%
df = clean_data("Dataset/songs_normalize.csv")
df.head()

# %% [markdown]
# show number of songs per year

# %%
analysis.songs_per_year(df)

# %% [markdown]
# visuallize trend of music over time

# %%
analysis.trend_over_time(df)
